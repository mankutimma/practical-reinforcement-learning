# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1
# Out:
# Starting virtual X frame buffer: Xvfb.
# env: DISPLAY=:1

# %% [markdown]
# ### OpenAI Gym
#
# We're gonna spend several next weeks learning algorithms that solve decision processes. We are then in need of some interesting decision problems to test our algorithms.
#
# That's where OpenAI gym comes into play. It's a python library that wraps many classical decision problems including robot control, videogames and board games.
#
# So here's how it works:

# %%
import gym
env = gym.make("MountainCar-v0")

plt.imshow(env.render('rgb_array'))
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation space: Box(2,)
# Action space: Discrete(3)

# %% [markdown]
# Note: if you're running this on your local machine, you'll see a window pop up with the image above. Don't close it, just alt-tab away.

# %% [markdown]
# ### Gym interface
#
# The three main methods of an environment are
# * __reset()__ - reset environment to initial state, _return first observation_
# * __render()__ - show current environment state (a more colorful version :) )
# * __step(a)__ - commit action __a__ and return (new observation, reward, is done, info)
#  * _new observation_ - an observation right after commiting the action __a__
#  * _reward_ - a number representing your reward for commiting action __a__
#  * _is done_ - True if the MDP has just finished, False if still in progress
#  * _info_ - some auxilary stuff about what just happened. Ignore it ~~for now~~.

# %%
obs0 = env.reset()
print("initial observation code:", obs0)

# Note: in MountainCar, observation is just two numbers: car position and velocity
# Out:
# initial observation code: [-0.59720706  0.        ]

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(0)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-5.97659478e-01 -4.52413666e-04]
# reward: -1.0
# is game over?: False

# %%
plt.imshow(env.render('rgb_array'))

# %% [markdown]
# ### Play with it
#
# Below is the code that drives the car to the right.
#
# However, it doesn't reach the flag at the far right due to gravity.
#
# __Your task__ is to fix it. Find a strategy that reaches the flag.
#
# You're not required to build any sophisticated algorithms for now, feel free to hard-code :)
#
# _Hint: your action at each step should depend either on __t__ or on __s__._

# %% [markdown]
# Velocity is negative if car moving left
#
# Position becomes more positive on moving right

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

def policy(t):
    # YOUR CODE HERE
    if(t<35):
        return actions['right']
    elif(35<=t<60):
        return actions['left']
    else:
        return actions['right']


for t in range(TIME_LIMIT):
    #s, r, done, _ = env.step(policy(t))
    s, r, done, info = env.step(policy(t))
    if(t % 5 ==0):
        print("Iteration {}: New observation = {}, Reward = {}, Game over = {}, info = {}".format(t, s, r, done, info))
    #draw game image on display
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <img src="data:image/png;base64,..." width="432">
# Iteration 0: New observation = [-4.01350544e-01  1.04283880e-04], Reward = -1.0, Game over = False, info = {}
# Iteration 5: New observation = [-0.39931553  0.00060045], Reward = -1.0, Game over = False, info = {}
# Iteration 10: New observation = [-0.39507831  0.00099325], Reward = -1.0, Game over = False, info = {}
# Iteration 15: New observation = [-0.38936629  0.00121585], Reward = -1.0, Game over = False, info = {}
# Iteration 20: New observation = [-0.38315442  0.00123149], Reward = -1.0, Game over = False, info = {}
# Iteration 25: New observation = [-0.37749532  0.00103909], Reward = -1.0, Game over = False, info = {}
# Iteration 30: New observation = [-0.37334075  0.00067246], Reward = -1.0, Game over = False, info = {}
# Iteration 35: New observation = [-0.37338493 -0.00180627], Reward = -1.0, Game over = False, info = {}
# Iteration 40: New observation = [-0.41300785 -0.01184421], Reward = -1.0, Game over = False, info = {}
# Iteration 45: New observation = [-0.49729171 -0.01980695], Reward = -1.0, Game over = False, info = {}
# Iteration 50: New observation = [-0.61102927 -0.02414981], Reward = -1.0, Game over = False, info = {}
# Iteration 55: New observation = [-0.73360496 -0.02419609], Reward = -1.0, Game over = False, info = {}
# Iteration 60: New observation = [-0.84286891 -0.0185498 ], Reward = -1.0, Game over = False, info = {}
# Iteration 65: New observation = [-0.8888843  -0.00283196], Reward = -1.0, Game over = False, info = {}
# Iteration 70: New observation = [-0.85489401  0.01315525], Reward = -1.0, Game over = False, info = {}
# Iteration 75: New observation = [-0.74436597  0.02774037], Reward = -1.0, Game over = False, info = {}
# Iteration 80: New observation = [-0.57170266  0.03831328], Reward = -1.0, Game over = False, info = {}
# Iteration 85: New observation = [-0.36576012  0.04209441], Reward = -1.0, Game over = False, info = {}
# Iteration 90: New observation = [-0.16240056  0.03895777], Reward = -1.0, Game over = False, info = {}
# Iteration 95: New observation = [0.01236299 0.03204466], Reward = -1.0, Game over = False, info = {}
# Iteration 100: New observation = [0.15074936 0.02491193], Reward = -1.0, Game over = False, info = {}
# Iteration 105: New observation = [0.25832379 0.01955321], Reward = -1.0, Game over = False, info = {}
# Iteration 110: New observation = [0.34634273 0.01664794], Reward = -1.0, Game over = False, info = {}
# Iteration 115: New observation = [0.42774355 0.01640277], Reward = -1.0, Game over = False, info = {}
# Iteration 120: New observation = [0.51661158 0.01911516], Reward = -1.0, Game over = True, info = {}
# Well done!
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Submit to coursera

# %%
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Submitted to Coursera platform. See results on assignment page!
